# %%
# !git clone https://github.com/singhjesika/AnimaGenAI.git
# %cd AnimaGenAI
# !pip install -r requirements.txt -q

# %%
from app.duration.pipeline import run_pipeline

output_path = run_pipeline(
 prompt="a fox exploring a glowing forest at night",
 duration_key="10s",
 style="anime",
)
print(output_path)

# %%
from IPython.display import Video
Video(output_path)
